# %%
import numpy as np
import cv2
import matplotlib 
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/kohli.jpg')
img.shape
# Out:
# (759, 630, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray
# Out:
# array([[134, 125, 114, ...,  93,  87,  86],
#        [114, 116, 115, ...,  94,  88,  92],
#        [112, 120, 124, ...,  85,  79,  91],
#        ...,
#        [144, 152, 142, ..., 113, 101,  97],
#        [141, 153, 147, ...,  94,  85,  90],
#        [150, 157, 151, ..., 103,  95,  97]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray,1.3,5)

# %%
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),4)
    roi_gray = gray[y:y+h,x:x+w]
    roi_color = face_img[y:y+h,x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,0,0),4)
        
plt.figure()
plt.imshow(face_img,cmap='gray')
plt.show()

# %% [markdown]
# - or cv.imshow('img',img) cv2.waitkey(0) cv.destroyallwindows()
