# %%
import numpy as np
import cv2
import matplotlib 
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/notime.png.')
img.shape
# Out:
# (400, 400, 3)

# %% [markdown]
# x and y + rgb coordinates

# %%
plt.imshow(img)

# %%
## to remove 3rd dimension and convert to grey image
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (400, 400)

# %%
gray
# Out:
# array([[ 82,  84,  82, ..., 104, 102, 103],
#        [ 83,  84,  83, ..., 101, 103, 104],
#        [ 85,  83,  83, ..., 100, 100, 106],
#        ...,
#        [ 57,  55,  54, ...,  61,  64,  64],
#        [ 56,  58,  57, ...,  65,  64,  64],
#        [ 55,  56,  55, ...,  63,  62,  60]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray,1.3,5)
faces
# Out:
# array([[134,  50, 132, 132]])

# %% [markdown]
# - array of x and y and width and height

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (134, 50, 132, 132)

# %%
start_point = (x,y)
end_point = (x+w,y+h)
thickness = 4
color = (0,255,0) # in green (rgb)
face_img = cv2.rectangle(img,start_point,end_point,color,thickness)
plt.imshow(face_img)

# %%
faces = face_cascade.detectMultiScale(gray,1.3,5)
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    roi_gray = gray[y:y+h,x:x+w]
    roi_color = face_img[y:y+h,x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,0,0),2)
        
plt.figure()
plt.imshow(face_img,cmap='gray')
plt.show()

# %%
plt.imshow(roi_color,cmap='gray')

# %% [markdown]
# faces = face_cascade.detectMultiScale(gray,1.3,5)
# for (x,y,w,h) in faces:
#     face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),4)
#     roi_gray = gray[y:y+h,x:x+w]
#     roi_color = face_img[y:y+h,x:x+w]
#     eyes = eye_cascade.detectMultiScale(roi_gray)
#     for (ex,ey,ew,eh) in eyes:
#         cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,0,0),4)
#
# cv2.imshow('img',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
## fun to get crop image if 2 eyes are detected
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
faces = face_cascade.detectMultiScale(gray,1.3,5)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/kohli.jpg')
plt.imshow(cropped_image)

# %%
org_image = cv2.imread('./test_images/kohli.jpg')
plt.imshow(org_image)

# %%
## se if it gives result for image with eyes<2
tx = cv2.imread('./test_images/bal.jpg')
# cv2.imshow('img',tx)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(tx)

# %%
crop = get_cropped_image_if_2_eyes('./test_images/bal.jpg')
crop

# %% [markdown]
# no result means eyes<2

# %%
path_to_data = "./Dataset/"
path_to_cr_data = "./Dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./Dataset/astrid',
#  './Dataset/curry',
#  './Dataset/j_balvin',
#  './Dataset/messi',
#  './Dataset/virat_kohli']

# %%
import shutil
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# astrid
# Generating cropped images in folder:  ./Dataset/cropped/astrid
# curry
# Generating cropped images in folder:  ./Dataset/cropped/curry
# j_balvin
# Generating cropped images in folder:  ./Dataset/cropped/j_balvin
# messi
# Generating cropped images in folder:  ./Dataset/cropped/messi
# virat_kohli
# Generating cropped images in folder:  ./Dataset/cropped/virat_kohli

# %% [markdown]
# Now you should have cropped folder under datasets folder that contains cropped images
# Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'astrid': ['./Dataset/cropped/astrid\\astrid1.png',
#   './Dataset/cropped/astrid\\astrid10.png',
#   './Dataset/cropped/astrid\\astrid11.png',
#   './Dataset/cropped/astrid\\astrid12.png',
#   './Dataset/cropped/astrid\\astrid13.png',
#   './Dataset/cropped/astrid\\astrid14.png',
#   './Dataset/cropped/astrid\\astrid15.png',
#   './Dataset/cropped/astrid\\astrid16.png',
#   './Dataset/cropped/astrid\\astrid17.png',
#   './Dataset/cropped/astrid\\astrid18.png',
#   './Dataset/cropped/astrid\\astrid19.png',
#   './Dataset/cropped/astrid\\astrid2.png',
#   './Dataset/cropped/astrid\\astrid20.png',
#   './Dataset/cropped/astrid\\astrid21.png',
#   './Dataset/cropped/astrid\\astrid22.png',
#   './Dataset/cropped/astrid\\astrid23.png',
#   './Dataset/cropped/astrid\\astrid24.png',
#   './Dataset/cropped/astrid\\astrid25.png',
#   './Dataset/cropped/astrid\\astrid26.png',
#   './Dataset/cropped/astrid\\astrid27.png',
#   './Dataset/cropped/astrid\\astrid28.png',
#   './Dataset/cropped/astrid\\astrid29.png',
#   './Dataset/cropped/astrid\\astrid3.png',
#   './Dataset/cropped/astrid\\astrid30.png',
#   './Dataset/cropped/astrid\\astrid31.png',
#   './Dataset/cropped/astrid\\astrid32.png',
#   './Dataset/cropped/astrid\\astrid33.png',
#   './Dataset/cropped/astrid\\astrid34.png',
#   './Dataset/cropped/astrid\\astrid35.png',
#   './Dataset/cropped/astrid\\astrid36.png',
#   './Dataset/cropped/astrid\\astrid37.png',
#   './Dataset/cropped/astrid\\astrid38.png',
#   './Dataset/cropped/astrid\\astrid39.png',
#   './Dataset/cropped/astrid\\astrid4.png',
#   './Dataset/cropped/astrid\\astrid40.png',
#   './Dataset/cropped/astrid\\astrid41.png',
#   './Dataset/cropped/astrid\\astrid42.png',
#   './Dataset/cropped/astrid\\astrid43.png',
#   './Dataset/cropped/astrid\\astrid44.png',
#   './Dataset/cropped/astrid\\astrid45.png',
#   './Dataset/cropped/astrid\\astrid46.png',
#   './Dataset/cropped/astrid\\astrid47.png',
#   './Dataset/cropped/astrid\\astrid48.png',
#   './Dataset/cropped/astrid\\astrid49.png',
#   './Dataset/cropped/astrid\\astrid5.png',
#   './Dataset/cropped/astrid\\astrid50.png',
#   './Dataset/cropped/astrid\\astrid51.png',
#   './Dataset/cropped/astrid\\astrid52.png',
#   './Dataset/cropped/astrid\\astrid53.png',
#   './Dataset/cropped/astrid\\astrid54.png',
#   './Dataset/cropped/astrid\\astrid55.png',
#   './Dataset/cropped/astrid\\astrid56.png',
#   './Dataset/cropped/astrid\\astrid57.png',
#   './Dataset/cropped/astrid\\astrid58.png',
#   './Dataset/cropped/astrid\\astrid6.png',
#   './Dataset/cropped/astrid\\astrid7.png',
#   './Dataset/cropped/astrid\\astrid8.png',
#   './Dataset/cropped/astrid\\astrid9.png'],
#  'curry': ['./Dataset/cropped/curry\\curry1.png',
#   './Dataset/cropped/curry\\curry10.png',
#   './Dataset/cropped/curry\\curry11.png',
#   './Dataset/cropped/curry\\curry12.png',
#   './Dataset/cropped/curry\\curry13.png',
#   './Dataset/cropped/curry\\curry14.png',
#   './Dataset/cropped/curry\\curry15.png',
#   './Dataset/cropped/curry\\curry16.png',
#   './Dataset/cropped/curry\\curry17.png',
#   './Dataset/cropped/curry\\curry18.png',
#   './Dataset/cropped/curry\\curry19.png',
#   './Dataset/cropped/curry\\curry2.png',
#   './Dataset/cropped/curry\\curry20.png',
#   './Dataset/cropped/curry\\curry21.png',
#   './Dataset/cropped/curry\\curry22.png',
#   './Dataset/cropped/curry\\curry23.png',
#   './Dataset/cropped/curry\\curry24.png',
#   './Dataset/cropped/curry\\curry25.png',
#   './Dataset/cropped/curry\\curry26.png',
#   './Dataset/cropped/curry\\curry27.png',
#   './Dataset/cropped/curry\\curry28.png',
#   './Dataset/cropped/curry\\curry29.png',
#   './Dataset/cropped/curry\\curry3.png',
#   './Dataset/cropped/curry\\curry30.png',
#   './Dataset/cropped/curry\\curry31.png',
#   './Dataset/cropped/curry\\curry32.png',
#   './Dataset/cropped/curry\\curry33.png',
#   './Dataset/cropped/curry\\curry34.png',
#   './Dataset/cropped/curry\\curry35.png',
#   './Dataset/cropped/curry\\curry36.png',
#   './Dataset/cropped/curry\\curry37.png',
#   './Dataset/cropped/curry\\curry38.png',
#   './Dataset/cropped/curry\\curry39.png',
#   './Dataset/cropped/curry\\curry4.png',
#   './Dataset/cropped/curry\\curry40.png',
#   './Dataset/cropped/curry\\curry41.png',
#   './Dataset/cropped/curry\\curry42.png',
#   './Dataset/cropped/curry\\curry43.png',
#   './Dataset/cropped/curry\\curry44.png',
#   './Dataset/cropped/curry\\curry45.png',
#   './Dataset/cropped/curry\\curry46.png',
#   './Dataset/cropped/curry\\curry48.png',
#   './Dataset/cropped/curry\\curry49.png',
#   './Dataset/cropped/curry\\curry5.png',
#   './Dataset/cropped/curry\\curry50.png',
#   './Dataset/cropped/curry\\curry51.png',
#   './Dataset/cropped/curry\\curry52.png',
#   './Dataset/cropped/curry\\curry6.png',
#   './Dataset/cropped/curry\\curry7.png',
#   './Dataset/cropped/curry\\curry8.png',
#   './Dataset/cropped/curry\\curry9.png'],
#  'j_balvin': ['./Dataset/cropped/j_balvin\\j_balvin1.png',
#   './Dataset/cropped/j_balvin\\j_balvin10.png',
#   './Dataset/cropped/j_balvin\\j_balvin11.png',
#   './Dataset/cropped/j_balvin\\j_balvin12.png',
#   './Dataset/cropped/j_balvin\\j_balvin13.png',
#   './Dataset/cropped/j_balvin\\j_balvin14.png',
#   './Dataset/cropped/j_balvin\\j_balvin15.png',
#   './Dataset/cropped/j_balvin\\j_balvin16.png',
#   './Dataset/cropped/j_balvin\\j_balvin17.png',
#   './Dataset/cropped/j_balvin\\j_balvin18.png',
#   './Dataset/cropped/j_balvin\\j_balvin19.png',
#   './Dataset/cropped/j_balvin\\j_balvin2.png',
#   './Dataset/cropped/j_balvin\\j_balvin20.png',
#   './Dataset/cropped/j_balvin\\j_balvin21.png',
#   './Dataset/cropped/j_balvin\\j_balvin22.png',
#   './Dataset/cropped/j_balvin\\j_balvin23.png',
#   './Dataset/cropped/j_balvin\\j_balvin25.png',
#   './Dataset/cropped/j_balvin\\j_balvin26.png',
#   './Dataset/cropped/j_balvin\\j_balvin27.png',
#   './Dataset/cropped/j_balvin\\j_balvin29.png',
#   './Dataset/cropped/j_balvin\\j_balvin3.png',
#   './Dataset/cropped/j_balvin\\j_balvin30.png',
#   './Dataset/cropped/j_balvin\\j_balvin31.png',
#   './Dataset/cropped/j_balvin\\j_balvin32.png',
#   './Dataset/cropped/j_balvin\\j_balvin4.png',
#   './Dataset/cropped/j_balvin\\j_balvin5.png',
#   './Dataset/cropped/j_balvin\\j_balvin6.png',
#   './Dataset/cropped/j_balvin\\j_balvin7.png',
#   './Dataset/cropped/j_balvin\\j_balvin8.png',
#   './Dataset/cropped/j_balvin\\j_balvin9.png'],
#  'messi': ['./Dataset/cropped/messi\\messi1.png',
#   './Dataset/cropped/messi\\messi10.png',
#   './Dataset/cropped/messi\\messi11.png',
#   './Dataset/cropped/messi\\messi12.png',
#   './Dataset/cropped/messi\\messi13.png',
#   './Dataset/cropped/messi\\messi14.png',
#   './Dataset/cropped/messi\\messi15.png',
#   './Dataset/cropped/messi\\messi17.png',
#   './Dataset/cropped/messi\\messi18.png',
#   './Dataset/cropped/messi\\messi19.png',
#   './Dataset/cropped/messi\\messi2.png',
#   './Dataset/cropped/messi\\messi20.png',
#   './Dataset/cropped/messi\\messi21.png',
#   './Dataset/cropped/messi\\messi22.png',
#   './Dataset/cropped/messi\\messi23.png',
#   './Dataset/cropped/messi\\messi24.png',
#   './Dataset/cropped/messi\\messi25.png',
#   './Dataset/cropped/messi\\messi26.png',
#   './Dataset/cropped/messi\\messi27.png',
#   './Dataset/cropped/messi\\messi28.png',
#   './Dataset/cropped/messi\\messi29.png',
#   './Dataset/cropped/messi\\messi3.png',
#   './Dataset/cropped/messi\\messi30.png',
#   './Dataset/cropped/messi\\messi32.png',
#   './Dataset/cropped/messi\\messi33.png',
#   './Dataset/cropped/messi\\messi34.png',
#   './Dataset/cropped/messi\\messi35.png',
#   './Dataset/cropped/messi\\messi36.png',
#   './Dataset/cropped/messi\\messi37.png',
#   './Dataset/cropped/messi\\messi38.png',
#   './Dataset/cropped/messi\\messi39.png',
#   './Dataset/cropped/messi\\messi4.png',
#   './Dataset/cropped/messi\\messi5.png',
#   './Dataset/cropped/messi\\messi6.png',
#   './Dataset/cropped/messi\\messi7.png',
#   './Dataset/cropped/messi\\messi8.png',
#   './Dataset/cropped/messi\\messi9.png'],
#  'virat_kohli': ['./Dataset/cropped/virat_kohli\\virat_kohli1.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli10.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli13.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli14.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli16.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli17.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli18.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli19.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli2.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli20.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli21.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli22.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli23.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli24.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli25.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli26.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli27.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli28.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli29.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli3.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli30.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli31.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli32.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli33.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli34.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli35.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli36.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli37.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli38.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli39.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli4.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli40.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli41.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli42.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli43.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli44.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli45.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli46.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli47.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli5.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli6.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli7.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli8.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli9.png']}

# %%
import numpy as np
import pywt
import cv2

# %%
celebrity_file_names_dict
# Out:
# {'astrid': ['./Dataset/cropped/astrid\\astrid1.png',
#   './Dataset/cropped/astrid\\astrid10.png',
#   './Dataset/cropped/astrid\\astrid11.png',
#   './Dataset/cropped/astrid\\astrid12.png',
#   './Dataset/cropped/astrid\\astrid13.png',
#   './Dataset/cropped/astrid\\astrid14.png',
#   './Dataset/cropped/astrid\\astrid15.png',
#   './Dataset/cropped/astrid\\astrid16.png',
#   './Dataset/cropped/astrid\\astrid17.png',
#   './Dataset/cropped/astrid\\astrid18.png',
#   './Dataset/cropped/astrid\\astrid19.png',
#   './Dataset/cropped/astrid\\astrid2.png',
#   './Dataset/cropped/astrid\\astrid20.png',
#   './Dataset/cropped/astrid\\astrid21.png',
#   './Dataset/cropped/astrid\\astrid22.png',
#   './Dataset/cropped/astrid\\astrid23.png',
#   './Dataset/cropped/astrid\\astrid24.png',
#   './Dataset/cropped/astrid\\astrid25.png',
#   './Dataset/cropped/astrid\\astrid26.png',
#   './Dataset/cropped/astrid\\astrid27.png',
#   './Dataset/cropped/astrid\\astrid28.png',
#   './Dataset/cropped/astrid\\astrid29.png',
#   './Dataset/cropped/astrid\\astrid3.png',
#   './Dataset/cropped/astrid\\astrid30.png',
#   './Dataset/cropped/astrid\\astrid31.png',
#   './Dataset/cropped/astrid\\astrid32.png',
#   './Dataset/cropped/astrid\\astrid33.png',
#   './Dataset/cropped/astrid\\astrid34.png',
#   './Dataset/cropped/astrid\\astrid35.png',
#   './Dataset/cropped/astrid\\astrid36.png',
#   './Dataset/cropped/astrid\\astrid37.png',
#   './Dataset/cropped/astrid\\astrid38.png',
#   './Dataset/cropped/astrid\\astrid39.png',
#   './Dataset/cropped/astrid\\astrid4.png',
#   './Dataset/cropped/astrid\\astrid40.png',
#   './Dataset/cropped/astrid\\astrid41.png',
#   './Dataset/cropped/astrid\\astrid42.png',
#   './Dataset/cropped/astrid\\astrid43.png',
#   './Dataset/cropped/astrid\\astrid44.png',
#   './Dataset/cropped/astrid\\astrid45.png',
#   './Dataset/cropped/astrid\\astrid46.png',
#   './Dataset/cropped/astrid\\astrid47.png',
#   './Dataset/cropped/astrid\\astrid48.png',
#   './Dataset/cropped/astrid\\astrid49.png',
#   './Dataset/cropped/astrid\\astrid5.png',
#   './Dataset/cropped/astrid\\astrid50.png',
#   './Dataset/cropped/astrid\\astrid51.png',
#   './Dataset/cropped/astrid\\astrid52.png',
#   './Dataset/cropped/astrid\\astrid53.png',
#   './Dataset/cropped/astrid\\astrid54.png',
#   './Dataset/cropped/astrid\\astrid55.png',
#   './Dataset/cropped/astrid\\astrid56.png',
#   './Dataset/cropped/astrid\\astrid57.png',
#   './Dataset/cropped/astrid\\astrid58.png',
#   './Dataset/cropped/astrid\\astrid6.png',
#   './Dataset/cropped/astrid\\astrid7.png',
#   './Dataset/cropped/astrid\\astrid8.png',
#   './Dataset/cropped/astrid\\astrid9.png'],
#  'curry': ['./Dataset/cropped/curry\\curry1.png',
#   './Dataset/cropped/curry\\curry10.png',
#   './Dataset/cropped/curry\\curry11.png',
#   './Dataset/cropped/curry\\curry12.png',
#   './Dataset/cropped/curry\\curry13.png',
#   './Dataset/cropped/curry\\curry14.png',
#   './Dataset/cropped/curry\\curry15.png',
#   './Dataset/cropped/curry\\curry16.png',
#   './Dataset/cropped/curry\\curry17.png',
#   './Dataset/cropped/curry\\curry18.png',
#   './Dataset/cropped/curry\\curry19.png',
#   './Dataset/cropped/curry\\curry2.png',
#   './Dataset/cropped/curry\\curry20.png',
#   './Dataset/cropped/curry\\curry21.png',
#   './Dataset/cropped/curry\\curry22.png',
#   './Dataset/cropped/curry\\curry23.png',
#   './Dataset/cropped/curry\\curry24.png',
#   './Dataset/cropped/curry\\curry25.png',
#   './Dataset/cropped/curry\\curry26.png',
#   './Dataset/cropped/curry\\curry27.png',
#   './Dataset/cropped/curry\\curry28.png',
#   './Dataset/cropped/curry\\curry29.png',
#   './Dataset/cropped/curry\\curry3.png',
#   './Dataset/cropped/curry\\curry30.png',
#   './Dataset/cropped/curry\\curry31.png',
#   './Dataset/cropped/curry\\curry32.png',
#   './Dataset/cropped/curry\\curry33.png',
#   './Dataset/cropped/curry\\curry34.png',
#   './Dataset/cropped/curry\\curry35.png',
#   './Dataset/cropped/curry\\curry36.png',
#   './Dataset/cropped/curry\\curry37.png',
#   './Dataset/cropped/curry\\curry38.png',
#   './Dataset/cropped/curry\\curry39.png',
#   './Dataset/cropped/curry\\curry4.png',
#   './Dataset/cropped/curry\\curry40.png',
#   './Dataset/cropped/curry\\curry41.png',
#   './Dataset/cropped/curry\\curry42.png',
#   './Dataset/cropped/curry\\curry43.png',
#   './Dataset/cropped/curry\\curry44.png',
#   './Dataset/cropped/curry\\curry45.png',
#   './Dataset/cropped/curry\\curry46.png',
#   './Dataset/cropped/curry\\curry48.png',
#   './Dataset/cropped/curry\\curry49.png',
#   './Dataset/cropped/curry\\curry5.png',
#   './Dataset/cropped/curry\\curry50.png',
#   './Dataset/cropped/curry\\curry51.png',
#   './Dataset/cropped/curry\\curry52.png',
#   './Dataset/cropped/curry\\curry6.png',
#   './Dataset/cropped/curry\\curry7.png',
#   './Dataset/cropped/curry\\curry8.png',
#   './Dataset/cropped/curry\\curry9.png'],
#  'j_balvin': ['./Dataset/cropped/j_balvin\\j_balvin1.png',
#   './Dataset/cropped/j_balvin\\j_balvin10.png',
#   './Dataset/cropped/j_balvin\\j_balvin11.png',
#   './Dataset/cropped/j_balvin\\j_balvin12.png',
#   './Dataset/cropped/j_balvin\\j_balvin13.png',
#   './Dataset/cropped/j_balvin\\j_balvin14.png',
#   './Dataset/cropped/j_balvin\\j_balvin15.png',
#   './Dataset/cropped/j_balvin\\j_balvin16.png',
#   './Dataset/cropped/j_balvin\\j_balvin17.png',
#   './Dataset/cropped/j_balvin\\j_balvin18.png',
#   './Dataset/cropped/j_balvin\\j_balvin19.png',
#   './Dataset/cropped/j_balvin\\j_balvin2.png',
#   './Dataset/cropped/j_balvin\\j_balvin20.png',
#   './Dataset/cropped/j_balvin\\j_balvin21.png',
#   './Dataset/cropped/j_balvin\\j_balvin22.png',
#   './Dataset/cropped/j_balvin\\j_balvin23.png',
#   './Dataset/cropped/j_balvin\\j_balvin25.png',
#   './Dataset/cropped/j_balvin\\j_balvin26.png',
#   './Dataset/cropped/j_balvin\\j_balvin27.png',
#   './Dataset/cropped/j_balvin\\j_balvin29.png',
#   './Dataset/cropped/j_balvin\\j_balvin3.png',
#   './Dataset/cropped/j_balvin\\j_balvin30.png',
#   './Dataset/cropped/j_balvin\\j_balvin31.png',
#   './Dataset/cropped/j_balvin\\j_balvin32.png',
#   './Dataset/cropped/j_balvin\\j_balvin4.png',
#   './Dataset/cropped/j_balvin\\j_balvin5.png',
#   './Dataset/cropped/j_balvin\\j_balvin6.png',
#   './Dataset/cropped/j_balvin\\j_balvin7.png',
#   './Dataset/cropped/j_balvin\\j_balvin8.png',
#   './Dataset/cropped/j_balvin\\j_balvin9.png'],
#  'messi': ['./Dataset/cropped/messi\\messi1.png',
#   './Dataset/cropped/messi\\messi10.png',
#   './Dataset/cropped/messi\\messi11.png',
#   './Dataset/cropped/messi\\messi12.png',
#   './Dataset/cropped/messi\\messi13.png',
#   './Dataset/cropped/messi\\messi14.png',
#   './Dataset/cropped/messi\\messi15.png',
#   './Dataset/cropped/messi\\messi17.png',
#   './Dataset/cropped/messi\\messi18.png',
#   './Dataset/cropped/messi\\messi19.png',
#   './Dataset/cropped/messi\\messi2.png',
#   './Dataset/cropped/messi\\messi20.png',
#   './Dataset/cropped/messi\\messi21.png',
#   './Dataset/cropped/messi\\messi22.png',
#   './Dataset/cropped/messi\\messi23.png',
#   './Dataset/cropped/messi\\messi24.png',
#   './Dataset/cropped/messi\\messi25.png',
#   './Dataset/cropped/messi\\messi26.png',
#   './Dataset/cropped/messi\\messi27.png',
#   './Dataset/cropped/messi\\messi28.png',
#   './Dataset/cropped/messi\\messi29.png',
#   './Dataset/cropped/messi\\messi3.png',
#   './Dataset/cropped/messi\\messi30.png',
#   './Dataset/cropped/messi\\messi32.png',
#   './Dataset/cropped/messi\\messi33.png',
#   './Dataset/cropped/messi\\messi34.png',
#   './Dataset/cropped/messi\\messi35.png',
#   './Dataset/cropped/messi\\messi36.png',
#   './Dataset/cropped/messi\\messi37.png',
#   './Dataset/cropped/messi\\messi38.png',
#   './Dataset/cropped/messi\\messi39.png',
#   './Dataset/cropped/messi\\messi4.png',
#   './Dataset/cropped/messi\\messi5.png',
#   './Dataset/cropped/messi\\messi6.png',
#   './Dataset/cropped/messi\\messi7.png',
#   './Dataset/cropped/messi\\messi8.png',
#   './Dataset/cropped/messi\\messi9.png'],
#  'virat_kohli': ['./Dataset/cropped/virat_kohli\\virat_kohli1.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli10.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli13.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli14.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli16.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli17.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli18.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli19.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli2.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli20.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli21.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli22.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli23.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli24.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli25.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli26.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli27.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli28.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli29.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli3.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli30.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli31.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli32.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli33.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli34.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli35.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli36.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli37.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli38.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli39.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli4.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli40.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli41.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli42.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli43.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli44.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli45.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli46.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli47.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli5.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli6.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli7.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli8.png',
#   './Dataset/cropped/virat_kohli\\virat_kohli9.png']}

# %% [markdown]
# # (3) Preprocessing: Use wavelet transform as a feature for traning our model
# In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc
# Wavelet transform

# %%
def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
img_har = w2d(cropped_image,'db1',5)
plt.imshow(img_har,cmap='gray')

# %% [markdown]
# You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier
# (3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region
# Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'astrid': 0, 'curry': 1, 'j_balvin': 2, 'messi': 3, 'virat_kohli': 4}

# %% [markdown]
# Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X) ## total images
# Out:
# 220

# %%
# size of each image
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 72],
#        [ 78],
#        [143],
#        ...,
#        [243],
#        [ 21],
#        [165]], dtype=uint8)

# %%
y[88] ## 1 is curry
# Out:
# 1

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (220, 4096)

# %% [markdown]
# #data cleaning is done
#
# Data cleaning process is done. Now we are ready to train our model
# We will use SVM with rbf kernel tuned with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.7636363636363637

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.92      0.71        12
#            1       0.82      0.75      0.78        12
#            2       0.75      0.75      0.75         4
#            3       1.00      0.50      0.67        16
#            4       0.85      1.00      0.92        11
#
#     accuracy                           0.76        55
#    macro avg       0.80      0.78      0.77        55
# weighted avg       0.82      0.76      0.76        55

# %% [markdown]
# Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.830303
# 1        random_forest    0.648485
# 2  logistic_regression    0.800000
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test) ##earlier error was with validation set
# Out:
# 0.7636363636363637

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.5636363636363636

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8727272727272727

# %%
best_clf = best_estimators['logistic_regression']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[11,  1,  0,  0,  0],
#        [ 1,  8,  2,  1,  0],
#        [ 0,  0,  4,  0,  0],
#        [ 1,  0,  1, 14,  0],
#        [ 0,  0,  0,  0, 11]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'astrid': 0, 'curry': 1, 'j_balvin': 2, 'messi': 3, 'virat_kohli': 4}

# %% [markdown]
# Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\abhis\anaconda3\lib\site-packages (1.1.0)
# ['saved_model.pkl']

# %% [markdown]
# Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
